# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]
n = len(A)

gauss_jacobi(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  # type: ignore
gauss_seidel(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  # type: ignore
# Out:
# [02-12 15:31:35][INFO][tj_bn] i= 0 x: [[0. 0.]]
# [02-12 15:31:35][INFO][tj_bn] i= 10 x: [[1.52539062 0.76269531]]
# [02-12 15:31:35][INFO][tj_bn] i= 0 x: [[0. 0.]]
# [02-12 15:31:35][INFO][tj_bn] i= 1 x: [[2.5  0.25]]
# [02-12 15:31:35][INFO][tj_bn] i= 2 x: [[2.375  0.4375]]
# [02-12 15:31:35][INFO][tj_bn] i= 3 x: [[2.28125  0.578125]]
# [02-12 15:31:35][INFO][tj_bn] i= 4 x: [[2.2109375  0.68359375]]
# [02-12 15:31:35][INFO][tj_bn] i= 5 x: [[2.15820312 0.76269531]]
# [02-12 15:31:35][INFO][tj_bn] i= 6 x: [[2.11865234 0.82202148]]
# [02-12 15:31:35][INFO][tj_bn] i= 7 x: [[2.08898926 0.86651611]]
# [02-12 15:31:35][INFO][tj_bn] i= 8 x: [[2.06674194 0.89988708]]
# [02-12 15:31:35][INFO][tj_bn] i= 9 x: [[2.05005646 0.92491531]]
# [02-12 15:31:35][INFO][tj_bn] i= 10 x: [[2.03754234 0.94368649]]
# array([[2.03754234],
#        [0.94368649]])

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 1.52539062, 0, 2.5, 2.375, 2.28125, 2.2109375, 2.15820312, 2.11865234, 2.08898926, 2.06674194, 2.05005646, 2.03754234 ]
y_values = [0, 0.76269531, 0, 0.25, 0.4375, 0.578125, 0.68359375, 0.76269531, 0.82202148, 0.86651611, 0.89988708, 0.92491531, 0.94368649]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[1,1],[-2,1]]
b = [6,0]
n = len(A)
gauss_jacobi(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  # type: ignore
gauss_seidel(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  # type: ignore
# Out:
# [02-12 15:45:44][INFO][tj_bn] i= 0 x: [[0. 0.]]
# [02-12 15:45:44][INFO][tj_bn] i= 10 x: [[ 66. 132.]]
# [02-12 15:45:44][INFO][tj_bn] i= 0 x: [[0. 0.]]
# [02-12 15:45:44][INFO][tj_bn] i= 1 x: [[ 6. 12.]]
# [02-12 15:45:44][INFO][tj_bn] i= 2 x: [[ -6. -12.]]
# [02-12 15:45:44][INFO][tj_bn] i= 3 x: [[18. 36.]]
# [02-12 15:45:44][INFO][tj_bn] i= 4 x: [[-30. -60.]]
# [02-12 15:45:44][INFO][tj_bn] i= 5 x: [[ 66. 132.]]
# [02-12 15:45:44][INFO][tj_bn] i= 6 x: [[-126. -252.]]
# [02-12 15:45:44][INFO][tj_bn] i= 7 x: [[258. 516.]]
# [02-12 15:45:44][INFO][tj_bn] i= 8 x: [[ -510. -1020.]]
# [02-12 15:45:44][INFO][tj_bn] i= 9 x: [[1026. 2052.]]
# [02-12 15:45:44][INFO][tj_bn] i= 10 x: [[-2046. -4092.]]
# array([[-2046.],
#        [-4092.]])

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 66, 0, 6, -6, 18, -30, 66, -126, 258, -510, 1026, -2046]
y_values = [0, 132, 0, 12, -12, 36, -60, 132, -252, 516, -1020, 2052, -4092]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
